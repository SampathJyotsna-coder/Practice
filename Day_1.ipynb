# %% [markdown]
# <a href="https://colab.research.google.com/github/SampathJyotsna-coder/Practice/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
print(a)
# Out:
# 5

# %%
a="10"
print(int(a))
# Out:
# 10

# %%
a=10
b=2
print(a+b)
# Out:
# 12

# %%
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
for i in range(1,5):
  print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 10
b = 20
sum = a + b
print("Sum =", sum)
# Out:
# Sum = 30

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 25
# Odd Number

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a > b:
    print(a, "is greater")
else:
    print(b, "is greater")
# Out:
# Enter first number: 2
# Enter second number: 6
# 6 is greater

# %%
num = int(input("Enter a number: "))
fact = 1
for i in range(1, num + 1):
    fact *= i
print("Factorial =", fact)
# Out:
# Enter a number: 5
# Factorial = 120

# %%
num = int(input("Enter a number: "))
for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number: 46
# 46 x 1 = 46
# 46 x 2 = 92
# 46 x 3 = 138
# 46 x 4 = 184
# 46 x 5 = 230
# 46 x 6 = 276
# 46 x 7 = 322
# 46 x 8 = 368
# 46 x 9 = 414
# 46 x 10 = 460

# %%
text = input("Enter a string: ")
print("Reversed string:", text[::-1])
# Out:
# Enter a string: this is jyotsna
# Reversed string: anstoyj si siht

# %%
num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print("Not Prime")
            break
    else:
        print("Prime Number")
else:
    print("Not Prime")
# Out:
# Enter a number: 22
# Not Prime

# %%
numbers = [10, 25, 5, 40, 18]
print("Largest number:", max(numbers))
# Out:
# Largest number: 40

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Enter first number: 23
# Enter second number: 32
# Addition: 55.0
# Subtraction: -9.0
# Multiplication: 736.0
# Division: 0.71875
