# %% [markdown]
# <a href="https://colab.research.google.com/github/SampathJyotsna-coder/Practice/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot([2,4,6,4])
plt.ylabel("numbers")
plt.xlabel("indices")
plt.title("my plot")
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.ylabel("squares")
plt.xlabel("numbers")
plt.title("myplot")
plt.grid()
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.ylabel("squares")
plt.xlabel("numbers")
plt.title("myplot")
plt.grid()
plt.show()

# %%
import numpy as np
t=np.arange(0.,5.,0.2)
plt.plot(t,t**2,'b--',label='^2')
plt.plot(t,t**2.2,'rs',label='^2.2')
plt.plot(t,t**2.5,'g^',label='^2.5')
plt.grid()
plt.legend()
plt.show()

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.bar(x,y)
plt.show()

# %%
x1=[1,2,3,4]
y1=[1,4,9,16]
x2=[1,2,3,4]
y2=[2,4,6,8]
lines=plt.plot(x1,y1,x2,y2)
plt.setp(lines,color='b',linewidth=2.0)
plt.show()

# %%
x1=[1,2,3,4]
y1=[1,4,9,16]
x2=[1,2,3,4]
y2=[2,4,6,8]
lines=plt.plot(x1,y1,x2,y2)
plt.setp(lines[0],color='r',linewidth=6.0)
plt.setp(lines[1],color='b',linewidth=6.0)
plt.show()

# %%
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/nyc_weather.csv')
print(df)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['Humidity'].min()
# Out:
# 33

# %%
df['EST'] [df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# np.float64(6.892857142857143)

# %% [markdown]
# Creating DataFrame

# %%
Weather_data=list(df.itertuples(index=False,name=None))
print(Weather_data)
# Out:
# [('1/1/2016', 38, 23, 52, 30.03, 10, 8.0, '0', 5, nan, 281), ('1/2/2016', 36, 18, 46, 30.02, 10, 7.0, '0', 3, nan, 275), ('1/3/2016', 40, 21, 47, 29.86, 10, 8.0, '0', 1, nan, 277), ('1/4/2016', 25, 9, 44, 30.05, 10, 9.0, '0', 3, nan, 345), ('1/5/2016', 20, -3, 41, 30.57, 10, 5.0, '0', 0, nan, 333), ('1/6/2016', 33, 4, 35, 30.5, 10, 4.0, '0', 0, nan, 259), ('1/7/2016', 39, 11, 33, 30.28, 10, 2.0, '0', 3, nan, 293), ('1/8/2016', 39, 29, 64, 30.2, 10, 4.0, '0', 8, nan, 79), ('1/9/2016', 44, 38, 77, 30.16, 9, 8.0, 'T', 8, 'Rain', 76), ('1/10/2016', 50, 46, 71, 29.59, 4, nan, '1.8', 7, 'Rain', 109), ('1/11/2016', 33, 8, 37, 29.92, 10, nan, '0', 1, nan, 289), ('1/12/2016', 35, 15, 53, 29.85, 10, 6.0, 'T', 4, nan, 235), ('1/13/2016', 26, 4, 42, 29.94, 10, 10.0, '0', 0, nan, 284), ('1/14/2016', 30, 12, 47, 29.95, 10, 5.0, 'T', 7, nan, 266), ('1/15/2016', 43, 31, 62, 29.82, 9, 5.0, 'T', 2, nan, 101), ('1/16/2016', 47, 37, 70, 29.52, 8, 7.0, '0.24', 7, 'Rain', 340), ('1/17/2016', 36, 23, 66, 2
# ...

# %%
df_filtered=df[['EST','Temperature','WindSpeedMPH','Events']].head(6)
print(df_filtered)
# Out:
#         EST  Temperature  WindSpeedMPH Events
# 0  1/1/2016           38           8.0    NaN
# 1  1/2/2016           36           7.0    NaN
# 2  1/3/2016           40           8.0    NaN
# 3  1/4/2016           25           9.0    NaN
# 4  1/5/2016           20           5.0    NaN
# 5  1/6/2016           33           4.0    NaN

# %%
df_filtered.shape
# Out:
# (6, 4)

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df[2:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.EST
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df[['EST','Events']]
# Out:
#           EST    Events
# 0    1/1/2016       NaN
# 1    1/2/2016       NaN
# 2    1/3/2016       NaN
# 3    1/4/2016       NaN
# 4    1/5/2016       NaN
# 5    1/6/2016       NaN
# 6    1/7/2016       NaN
# 7    1/8/2016       NaN
# 8    1/9/2016      Rain
# 9   1/10/2016      Rain
# 10  1/11/2016       NaN
# 11  1/12/2016       NaN
# 12  1/13/2016       NaN
# 13  1/14/2016       NaN
# 14  1/15/2016       NaN
# 15  1/16/2016      Rain
# 16  1/17/2016  Fog-Snow
# 17  1/18/2016      Snow
# 18  1/19/2016       NaN
# 19  1/20/2016       NaN
# 20  1/21/2016       NaN
# 21  1/22/2016      Snow
# 22  1/23/2016  Fog-Snow
# 23  1/24/2016      Snow
# 24  1/25/2016       NaN
# 25  1/26/2016       NaN
# 26  1/27/2016      Rain
# 27  1/28/2016       NaN
# 28  1/29/2016       NaN
# 29  1/30/2016       NaN
# 30  1/31/2016       NaN

# %%
print(df['Temperature'].max())
df['Temperature'].min()
# Out:
# 50
# 20

# %%
print(df['Temperature'].mean())
# Out:
# 34.67741935483871

# %%
print(df['Temperature'].mean())
print(df['Temperature'].std())
df.describe()
# Out:
# 34.67741935483871
# 7.639315400279415
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/nyc_weather_1.csv')
print(df)
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
g=df.groupby('City')
g

# %%
import pandas as pd
india_weather=pd.DataFrame({
    "City":["afg","india","sa"],
    "Temperature":[32,45,30],
    "Humidity":[80,60,78]
    })
india_weather
# Out:
#     City  Temperature  Humidity
# 0    afg           32        80
# 1  india           45        60
# 2     sa           30        78

# %%
import pandas as pd
US_weather=pd.DataFrame({
    "City":["chicago","orlando","newyork"],
    "Temperature":[21,14,35],
    "Humidity":[68,65,75]
})
US_weather
# Out:
#       City  Temperature  Humidity
# 0  chicago           21        68
# 1  orlando           14        65
# 2  newyork           35        75

# %%
df=pd.concat([india_weather,US_weather])
df
# Out:
#       City  Temperature  Humidity
# 0      afg           32        80
# 1    india           45        60
# 2       sa           30        78
# 0  chicago           21        68
# 1  orlando           14        65
# 2  newyork           35        75

# %%
df=pd.concat([india_weather,US_weather],axis=1)
df
# Out:
#     City  Temperature  Humidity     City  Temperature  Humidity
# 0    afg           32        80  chicago           21        68
# 1  india           45        60  orlando           14        65
# 2     sa           30        78  newyork           35        75
